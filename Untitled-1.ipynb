# %%
# Out:
# ---------------------------------------------------------------------------
# PySparkRuntimeError                       Traceback (most recent call last)
# Cell In[3], line 9
#       1 # Spark Session
#       2 from pyspark.sql import SparkSession
#       4 spark = (
#       5     SparkSession
#       6     .builder
#       7     .appName("Joem")
#       8     .master("local[*]")
# ----> 9     .getOrCreate()
#      10 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pyspark\sql\session.py:557, in SparkSession.Builder.getOrCreate(self)
#     555     sparkConf.set(key, value)
#     556 # This SparkContext may be an existing one.
# --> 557 sc = SparkContext.getOrCreate(sparkConf)
#     558 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     559 # by all sessions.
#     560 session = SparkSession(sc, options=self._options)
#
# ...

# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/455.4 MB ? eta -:--:--
#      ---------------------------------------- 0.5/455.4 MB 9.5 MB/s eta 0:00:48
#      ---------------------------------------- 2.4/455.4 MB 9.1 MB/s eta 0:00:50
#      ---------------------------------------- 3.9/455.4 MB 8.5 MB/s eta 0:00:54
#      ---------------------------------------- 5.5/455.4 MB 8.0 MB/s eta 0:00:57
#       --------------------------------------- 6.6/455.4 MB 7.3 MB/s eta 0:01:02
#       --------------------------------------- 6.6/455.4 MB 7.3 MB/s eta 0:01:02
#       --------------------------------------- 7.6/455.4 MB 6.0 MB/s eta 0:01:15
#       --------------------------------------- 7.9/455.4 MB 5.9 MB/s eta 0:01:17
#       --------------------------------------- 8.9/455.4 MB 5.2 MB/s eta 0:01:26
#       --------------------------------------- 9.4/455.4 MB 5.0 MB/s eta 0:01:29
# ...
